# %%
# !pip install requests
# !pip install IPython
# !pip install pandas

# %%
import requests
import pandas as pd

from IPython.display import display

with open('api_key_tmbd.txt') as arquivo:
  api_key = arquivo.read()

url = f"https://api.themoviedb.org/3/movie/top_rated?api_key={api_key}&language=pt-BR"


response = requests.get(url)
data = response.json()

filmes = []


for movie in data['results']:
  df = {'Titulo': movie['title'],
  'Data de lançamento': movie['release_date'],
  'Visão geral': movie['overview'],
  'Votos': movie['vote_count'],
  'Média de votos:': movie['vote_average']}
  
  filmes.append(df)


df = pd.DataFrame(filmes)
display(df)
# Out:
#                                    Titulo Data de lançamento  \
# 0                       O Poderoso Chefão         1972-03-14
# 1                   Um Sonho de Liberdade         1994-09-23
# 2    Homem-Aranha: Através do Aranhaverso         2023-05-31
# 3             O Poderoso Chefão: Parte II         1974-12-20
# 4                    A Lista de Schindler         1993-12-15
# 5               Dilwale vai levar a noiva         1995-10-19
# 6                     A Viagem de Chihiro         2001-07-20
# 7                12 Homens e Uma Sentença         1957-04-10
# 8                              Your Name.         2016-08-26
# 9                                Parasita         2019-05-30
# 10                 À Espera de um Milagre         1999-12-10
# 11         Batman: O Cavaleiro das Trevas         2008-07-14
# 12                       Cuando Sea Joven         2022-09-14
# 13       Pulp Fiction: Tempo de Violência         1994-09-10
# 14  Forrest Gump: O Contador de Histórias         1994-06-23
# 15                Três Homens em Conflito         1966-12-23
# 16   O Senhor dos Anéis: O Retorno do Rei         2003-12-01
# 17              Primal: Tales of Savagery         2019-11-21
# 18                   Os Bons Companheiros         1990-09-12
# 19                        Cinema Paradiso         1988-11-17
#
#                                           Visão geral  Votos  Média de votos:
# 0   Em 1945, Don Corleone é o chefe de uma mafiosa...  18106              8.7
# 1   Em 1946, Andy Dufresne, um banqueiro jovem e b...  23976              8.7
# 2   Miles Morales retorna para o próximo capítulo ...   1525              8.7
# 3   Após a máfia matar sua família, o jovem Vito f...  10930              8.6
# 4   O alemão Oskar Schindler viu na mão de obra ju...  14183              8.6
# 5   Raj e Simran são dois jovens indianos vivendo ...   4150              8.6
# 6   Chihiro e seus pais estão se mudando para uma ...  14436              8.5
# 7   Um jovem porto-riquenho é acusado do brutal cr...   7348              8.5
# 8   Mitsuha é a filha do prefeito de uma pequena c...   9941              8.5
# 9   Toda a família de Ki-taek está desempregada, v...  15895              8.5
# 10  Milagres acontecem em lugares inesperados, mes...  15519              8.5
# 11  Após dois anos desde o surgimento do Batman, o...  29899              8.5
# 12                                                       243              8.5
# 13  Vincent Vega (John Travolta) e Jules Winnfield...  25325              8.5
# 14  Quarenta anos da história dos Estados Unidos, ...  24818              8.5
# 15  Durante o auge da Guerra Civil, um misterioso ...   7466              8.5
# 16  O confronto final entre as forças do bem e do ...  21736              8.5
# 17                                                       265              8.5
# 18  Um jovem cresce na máfia e trabalha arduamente...  11353              8.5
# 19  Um diretor de cinema lembra como, em sua infân...   3793              8.5
